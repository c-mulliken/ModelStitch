# %%
import sys
sys.path.append('..')
from src.autoencoder import Autoencoder
from src.data import *
import matplotlib.pyplot as plt
import importlib

# %%
fig, axs = plt.subplots(2, 8, figsize=(15, 4))

for i in range(8):
    M.eval()
    input, _ = MNIST_testset[i]
    raw_im = input.detach().numpy().reshape(28, 28)
    pred_im = M(input.view(1, -1)).detach().numpy().reshape(28, 28)
    axs[0, i].imshow(raw_im, cmap='gray')
    axs[1, i].imshow(pred_im, cmap='gray')
    axs[0, i].axis(False); axs[1, i].axis(False)
plt.tight_layout()

# %%
M = Autoencoder(784, 10, [300, 300, 300, 300])
M.train_now(MNIST_trainset, epochs=10)
M.viz_latent_space(MNIST_testloader)
# Out:
# Epoch: 0 | Loss: 98.0951874256134
# Epoch: 1 | Loss: 84.06225293502212
# Epoch: 2 | Loss: 76.95353514887393
# Epoch: 3 | Loss: 75.10160030424595
# Epoch: 4 | Loss: 73.94823712855577
# Epoch: 5 | Loss: 73.52298205159605
# Epoch: 6 | Loss: 73.32462580315769
# Epoch: 7 | Loss: 72.87282842770219
# Epoch: 8 | Loss: 72.51039010472596
# Epoch: 9 | Loss: 72.76342525333166
# Latent space dim 10 > 2, using PCA.
# /Users/cobymulliken/Desktop/Repositories/model-stitch/experiments/../src/autoencoder.py:85: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
